# %%
pip install tensorflow
# Out:
# Collecting tensorflowNote: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/tensorflow/
#   Using cached tensorflow-2.12.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Using cached tensorflow_intel-2.12.0-cp39-cp39-win_amd64.whl (272.8 MB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (21.3)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.9)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (63.4.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hp\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.37.1)
# Requirement already satisfied: scipy>=1.7 in c:\users\hp\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.9.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\hp\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.18.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hp\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow) (3.0.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.11)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hp\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Installing collected packages: tensorflow-intel, tensorflow
# Successfully installed tensorflow-2.12.0 tensorflow-intel-2.12.0

# %%
pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\hp\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.10)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (63.4.1)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (21.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.9)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hp\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.37.1)
# Requirement already satisfied: scipy>=1.7 in c:\users\hp\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.9.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\hp\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.18.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hp\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.11)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hp\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\hp\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/tensorflow/

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data1=pd.read_excel("E:/DSBDA/gold2021.xlsx")
data2=pd.read_excel("E:/DSBDA/gold2020.xlsx")
data3=pd.read_excel("E:/DSBDA/gold2019.xlsx")
data4=pd.read_excel("E:/DSBDA/gold2018.xlsx")

# %%
data=pd.concat([data1,data2,data3,data4])
data=data.sort_values(by='DATE', ascending=True)
data = data.loc[:, ~data.columns.str.contains('^Unnamed')]
data=data.set_index('DATE')

# %%
data
# Out:
#             Price
# DATE
# 2018-10-12  31876
# 2018-10-15  32264
# 2018-10-16  32109
# 2018-10-17  32043
# 2018-10-18  32037
# ...           ...
# 2021-11-29  48042
# 2021-11-30  48085
# 2021-12-01  47633
# 2021-12-02  47402
# 2021-12-03  47475
#
# [758 rows x 1 columns]

# %% [markdown]
# ## Seasonal Naive Model

# %%
from sklearn.model_selection import train_test_split

# %%
# separate out a validation dataset
split_point = len(data)-152
dataset, validation = data[0:split_point], data[split_point:]
print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
dataset.to_csv('dataset.csv', header=False)
validation.to_csv('validation.csv', header=False)
# Out:
# Dataset 606, Validation 152

# %%
# evaluate a persistence model
from pandas import read_csv
from sklearn.metrics import mean_squared_error
from math import sqrt

# evaluate a persistence model
train = read_csv('dataset.csv', header=None, index_col=0, parse_dates=True, squeeze=True)
# prepare data
X = train.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]

# %%
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    yhat = history[-1]
    predictions.append(yhat)
# observation
    obs = test[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%.3f' % (yhat, obs))
# report performance
rmse = sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)
# Out:
# >Predicted=43076.000, Expected=42729.000
# >Predicted=42729.000, Expected=42429.000
# >Predicted=42429.000, Expected=42024.000
# >Predicted=42024.000, Expected=42376.000
# >Predicted=42376.000, Expected=42585.000
# >Predicted=42585.000, Expected=42613.000
# >Predicted=42613.000, Expected=42416.000
# >Predicted=42416.000, Expected=42351.000
# >Predicted=42351.000, Expected=42598.000
# >Predicted=42598.000, Expected=42590.000
# >Predicted=42590.000, Expected=42712.000
# >Predicted=42712.000, Expected=42933.000
# >Predicted=42933.000, Expected=43438.000
# >Predicted=43438.000, Expected=43515.000
# >Predicted=43515.000, Expected=43508.000
# >Predicted=43508.000, Expected=45377.000
# >Predicted=45377.000, Expected=44656.000
# >Predicted=44656.000, Expected=44449.000
# >Predicted=44449.000, Expected=44408.000
# >Predicted=44408.000, Expected=44200.000
# >Predicted=44200.000, Expected=43982.000
# >Predicted=43982.000, Expected=44025.000
# >Predicted=44025.000, Expected=45034.000
# >Predicted=45034.000, Expected=45140.000
# >Predicted=45140.000, Expected=46455.000
# >Predicted=46455.000, Expected=45659.000
# >Predicted=45659.000, Expected=45651.000
# >Predicted=45651.000, Expected=45310.000
# >Predicted=45310.000, Expected=45061.000
# >Predicted=45061.000, Expected=43571.000
# >Predicted=43571.000, Expected=42294.000
# >Predicted=42294.000, Expected=41509.000
# >Predicted=41509.000, Expected=42468.000
# >Predicted=42468.000, Expected=42078.000
# >Predicted=42078.000, Expected=42881.000
# >Predicted=42881.000, Expected=42920.000
# >Predicted=42920.000, Expected=42940.000
# >Predicted=42940.000, Expected=42932.000
# >Predicted=42932.000, Expected=42931.000
# >Predicted=42931.000, Expected=42859.000
# >Predicted=42859.000, Expected=42817.000
# >Predicted=42817.000, Expected=42810.000
# >Predicted=42810.000, Expected=42803.000
# >Predicted=42803.000, Expected=42732.000
# >Predicted=42732.000, Expected=42688.000
# >Predicted=42688.000, Expected=42670.000
# >Predicted=42670.000, Expected=42661.000
# >Predicted=42661.000, Expected=42629.000
# >Predicted=42629.000, Expected=42611.000
# >Predicted=42611.000, Expected=42569.000
# >Predicted=42569.000, Expected=42544.000
# >Predicted=42544.000, Expected=42501.000
# >Predicted=42501.000, Expected=42495.000
# >Predicted=42495.000, Expected=42489.000
# >Predicted=42489.000, Expected=42477.000
# >Predicted=42477.000, Expected=42471.000
# >Predicted=42471.000, Expected=42455.000
# >Predicted=42455.000, Expected=42449.000
# >Predicted=42449.000, Expected=42446.000
# >Predicted=42446.000, Expected=42439.000
# >Predicted=42439.000, Expected=42433.000
# >Predicted=42433.000, Expected=42415.000
# >Predicted=42415.000, Expected=42401.000
# >Predicted=42401.000, Expected=42393.000
# >Predicted=42393.000, Expected=42387.000
# >Predicted=42387.000, Expected=42371.000
# >Predicted=42371.000, Expected=42353.000
# >Predicted=42353.000, Expected=42354.000
# >Predicted=42354.000, Expected=42336.000
# >Predicted=42336.000, Expected=42334.000
# >Predicted=42334.000, Expected=42328.000
# >Predicted=42328.000, Expected=42308.000
# >Predicted=42308.000, Expected=42306.000
# >Predicted=42306.000, Expected=42296.000
# >Predicted=42296.000, Expected=42283.000
# >Predicted=42283.000, Expected=42247.000
# >Predicted=42247.000, Expected=42230.000
# >Predicted=42230.000, Expected=42206.000
# >Predicted=42206.000, Expected=42192.000
# >Predicted=42192.000, Expected=42182.000
# >Predicted=42182.000, Expected=42174.000
# >Predicted=42174.000, Expected=48276.000
# >Predicted=48276.000, Expected=48094.000
# >Predicted=48094.000, Expected=47765.000
# >Predicted=47765.000, Expected=47649.000
# >Predicted=47649.000, Expected=47559.000
# >Predicted=47559.000, Expected=47373.000
# >Predicted=47373.000, Expected=47746.000
# >Predicted=47746.000, Expected=47937.000
# >Predicted=47937.000, Expected=48327.000
# >Predicted=48327.000, Expected=48350.000
# >Predicted=48350.000, Expected=47855.000
# >Predicted=47855.000, Expected=48493.000
# >Predicted=48493.000, Expected=48268.000
# >Predicted=48268.000, Expected=48486.000
# >Predicted=48486.000, Expected=48608.000
# >Predicted=48608.000, Expected=49009.000
# >Predicted=49009.000, Expected=49021.000
# >Predicted=49021.000, Expected=49586.000
# >Predicted=49586.000, Expected=48993.000
# >Predicted=48993.000, Expected=49149.000
# >Predicted=49149.000, Expected=49404.000
# >Predicted=49404.000, Expected=49379.000
# >Predicted=49379.000, Expected=49856.000
# >Predicted=49856.000, Expected=49245.000
# >Predicted=49245.000, Expected=49262.000
# >Predicted=49262.000, Expected=49030.000
# >Predicted=49030.000, Expected=49218.000
# >Predicted=49218.000, Expected=49978.000
# >Predicted=49978.000, Expected=50179.000
# >Predicted=50179.000, Expected=50056.000
# >Predicted=50056.000, Expected=50092.000
# >Predicted=50092.000, Expected=49889.000
# >Predicted=49889.000, Expected=50029.000
# >Predicted=50029.000, Expected=49981.000
# >Predicted=49981.000, Expected=49822.000
# >Predicted=49822.000, Expected=49886.000
# >Predicted=49886.000, Expected=50118.000
# >Predicted=50118.000, Expected=50825.000
# >Predicted=50825.000, Expected=51490.000
# >Predicted=51490.000, Expected=51797.000
# >Predicted=51797.000, Expected=53218.000
# >Predicted=53218.000, Expected=53204.000
# >Predicted=53204.000, Expected=53735.000
# >Predicted=53735.000, Expected=53879.000
# >Predicted=53879.000, Expected=54515.000
# >Predicted=54515.000, Expected=54554.000
# >Predicted=54554.000, Expected=54623.000
# >Predicted=54623.000, Expected=56060.000
# >Predicted=56060.000, Expected=56477.000
# >Predicted=56477.000, Expected=56834.000
# >Predicted=56834.000, Expected=56167.000
# >Predicted=56167.000, Expected=54745.000
# >Predicted=54745.000, Expected=54736.000
# >Predicted=54736.000, Expected=53171.000
# >Predicted=53171.000, Expected=53488.000
# >Predicted=53488.000, Expected=53420.000
# >Predicted=53420.000, Expected=54481.000
# >Predicted=54481.000, Expected=53977.000
# >Predicted=53977.000, Expected=52938.000
# >Predicted=52938.000, Expected=52903.000
# >Predicted=52903.000, Expected=52607.000
# >Predicted=52607.000, Expected=52076.000
# >Predicted=52076.000, Expected=51722.000
# >Predicted=51722.000, Expected=51967.000
# >Predicted=51967.000, Expected=51512.000
# >Predicted=51512.000, Expected=51936.000
# >Predicted=51936.000, Expected=52113.000
# >Predicted=52113.000, Expected=51780.000
# >Predicted=51780.000, Expected=51456.000
# >Predicted=51456.000, Expected=51507.000
# >Predicted=51507.000, Expected=51526.000
# >Predicted=51526.000, Expected=51446.000
# >Predicted=51446.000, Expected=51624.000
# >Predicted=51624.000, Expected=51947.000
# >Predicted=51947.000, Expected=51752.000
# >Predicted=51752.000, Expected=51726.000
# >Predicted=51726.000, Expected=52348.000
# >Predicted=52348.000, Expected=52332.000
# >Predicted=52332.000, Expected=51905.000
# >Predicted=51905.000, Expected=52107.000
# >Predicted=52107.000, Expected=51576.000
# >Predicted=51576.000, Expected=50993.000
# >Predicted=50993.000, Expected=50663.000
# >Predicted=50663.000, Expected=49962.000
# >Predicted=49962.000, Expected=50151.000
# >Predicted=50151.000, Expected=49805.000
# >Predicted=49805.000, Expected=50682.000
# >Predicted=50682.000, Expected=50618.000
# >Predicted=50618.000, Expected=50569.000
# >Predicted=50569.000, Expected=50730.000
# >Predicted=50730.000, Expected=51104.000
# >Predicted=51104.000, Expected=50446.000
# >Predicted=50446.000, Expected=50518.000
# >Predicted=50518.000, Expected=50899.000
# >Predicted=50899.000, Expected=51292.000
# >Predicted=51292.000, Expected=51207.000
# >Predicted=51207.000, Expected=50673.000
# >Predicted=50673.000, Expected=50672.000
# >Predicted=50672.000, Expected=50957.000
# >Predicted=50957.000, Expected=51030.000
# >Predicted=51030.000, Expected=50995.000
# >Predicted=50995.000, Expected=51420.000
# >Predicted=51420.000, Expected=51383.000
# >Predicted=51383.000, Expected=51185.000
# >Predicted=51185.000, Expected=51227.000
# >Predicted=51227.000, Expected=51101.000
# >Predicted=51101.000, Expected=51062.000
# >Predicted=51062.000, Expected=50785.000
# >Predicted=50785.000, Expected=50805.000
# >Predicted=50805.000, Expected=51073.000
# >Predicted=51073.000, Expected=51228.000
# >Predicted=51228.000, Expected=51219.000
# >Predicted=51219.000, Expected=51503.000
# >Predicted=51503.000, Expected=52214.000
# >Predicted=52214.000, Expected=52446.000
# >Predicted=52446.000, Expected=50521.000
# >Predicted=50521.000, Expected=50690.000
# >Predicted=50690.000, Expected=50652.000
# >Predicted=50652.000, Expected=50858.000
# >Predicted=50858.000, Expected=50852.000
# >Predicted=50852.000, Expected=50842.000
# >Predicted=50842.000, Expected=50969.000
# >Predicted=50969.000, Expected=50580.000
# >Predicted=50580.000, Expected=50206.000
# >Predicted=50206.000, Expected=50282.000
# >Predicted=50282.000, Expected=50306.000
# >Predicted=50306.000, Expected=49228.000
# >Predicted=49228.000, Expected=49018.000
# >Predicted=49018.000, Expected=49077.000
# >Predicted=49077.000, Expected=48942.000
# >Predicted=48942.000, Expected=48928.000
# >Predicted=48928.000, Expected=48161.000
# >Predicted=48161.000, Expected=48931.000
# >Predicted=48931.000, Expected=49277.000
# >Predicted=49277.000, Expected=49139.000
# >Predicted=49139.000, Expected=51772.000
# >Predicted=51772.000, Expected=52616.000
# >Predicted=52616.000, Expected=53154.000
# >Predicted=53154.000, Expected=53406.000
# >Predicted=53406.000, Expected=52484.000
# >Predicted=52484.000, Expected=51945.000
# >Predicted=51945.000, Expected=51064.000
# >Predicted=51064.000, Expected=51186.000
# >Predicted=51186.000, Expected=50980.000
# >Predicted=50980.000, Expected=50975.000
# >Predicted=50975.000, Expected=50825.000
# >Predicted=50825.000, Expected=50438.000
# >Predicted=50438.000, Expected=50613.000
# >Predicted=50613.000, Expected=50704.000
# >Predicted=50704.000, Expected=51089.000
# >Predicted=51089.000, Expected=50718.000
# >Predicted=50718.000, Expected=50625.000
# >Predicted=50625.000, Expected=50472.000
# >Predicted=50472.000, Expected=50397.000
# >Predicted=50397.000, Expected=50596.000
# >Predicted=50596.000, Expected=50119.000
# >Predicted=50119.000, Expected=49762.000
# >Predicted=49762.000, Expected=49337.000
# >Predicted=49337.000, Expected=48824.000
# >Predicted=48824.000, Expected=48623.000
# >Predicted=48623.000, Expected=48753.000
# >Predicted=48753.000, Expected=49472.000
# >Predicted=49472.000, Expected=49306.000
# >Predicted=49306.000, Expected=49334.000
# >Predicted=49334.000, Expected=48656.000
# >Predicted=48656.000, Expected=48608.000
# >Predicted=48608.000, Expected=48716.000
# >Predicted=48716.000, Expected=47926.000
# >Predicted=47926.000, Expected=47611.000
# >Predicted=47611.000, Expected=47309.000
# >Predicted=47309.000, Expected=47974.000
# >Predicted=47974.000, Expected=48093.000
# >Predicted=48093.000, Expected=47958.000
# >Predicted=47958.000, Expected=47714.000
# >Predicted=47714.000, Expected=47793.000
# >Predicted=47793.000, Expected=47152.000
# >Predicted=47152.000, Expected=46574.000
# >Predicted=46574.000, Expected=46260.000
# >Predicted=46260.000, Expected=45901.000
# >Predicted=45901.000, Expected=45574.000
# >Predicted=45574.000, Expected=45612.000
# >Predicted=45612.000, Expected=45691.000
# >Predicted=45691.000, Expected=45875.000
# >Predicted=45875.000, Expected=45870.000
# >Predicted=45870.000, Expected=45443.000
# >Predicted=45443.000, Expected=45969.000
# >Predicted=45969.000, Expected=45963.000
# >Predicted=45963.000, Expected=46047.000
# >Predicted=46047.000, Expected=46024.000
# >Predicted=46024.000, Expected=46046.000
# >Predicted=46046.000, Expected=45850.000
# >Predicted=45850.000, Expected=46044.000
# >Predicted=46044.000, Expected=45950.000
# >Predicted=45950.000, Expected=45909.000
# >Predicted=45909.000, Expected=45841.000
# >Predicted=45841.000, Expected=45827.000
# >Predicted=45827.000, Expected=45433.000
# >Predicted=45433.000, Expected=45184.000
# >Predicted=45184.000, Expected=46024.000
# >Predicted=46024.000, Expected=46144.000
# >Predicted=46144.000, Expected=46346.000
# >Predicted=46346.000, Expected=47109.000
# >Predicted=47109.000, Expected=47317.000
# >Predicted=47317.000, Expected=47346.000
# >Predicted=47346.000, Expected=47521.000
# >Predicted=47521.000, Expected=47421.000
# >Predicted=47421.000, Expected=47416.000
# >Predicted=47416.000, Expected=47716.000
# >Predicted=47716.000, Expected=48018.000
# >Predicted=48018.000, Expected=48708.000
# >Predicted=48708.000, Expected=48236.000
# >Predicted=48236.000, Expected=48231.000
# >Predicted=48231.000, Expected=48731.000
# >Predicted=48731.000, Expected=48680.000
# >Predicted=48680.000, Expected=48337.000
# >Predicted=48337.000, Expected=48304.000
# >Predicted=48304.000, Expected=47790.000
# >Predicted=47790.000, Expected=47791.000
# >Predicted=47791.000, Expected=47595.000
# >Predicted=47595.000, Expected=47857.000
# >Predicted=47857.000, Expected=47814.000
# >Predicted=47814.000, Expected=47640.000
# RMSE: 578.230

# %% [markdown]
# ### Time series decomposition

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

decompose_ts_add = seasonal_decompose(data.Price, period=12)
decompose_ts_add.plot()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plt.rcParams.update({'figure.figsize':(17,12), 'figure.dpi':120})

# %%
# Original Series
fig, axes = plt.subplots(3, 2)
axes[0, 0].plot(data.Price); axes[0, 0].set_title('Original Series')
plot_acf(data.Price, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(data.Price.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(data.Price.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(data.Price.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(data.Price.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp39-cp39-win_amd64.whl (572 kB)
#      -------------------------------------- 572.7/572.7 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in c:\users\hp\anaconda3\lib\site-packages (from pmdarima) (1.26.11)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\hp\anaconda3\lib\site-packages (from pmdarima) (0.29.32)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\hp\anaconda3\lib\site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\hp\anaconda3\lib\site-packages (from pmdarima) (1.9.1)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\hp\anaconda3\lib\site-packages (from pmdarima) (63.4.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\hp\anaconda3\lib\site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\hp\anaconda3\lib\site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\hp\anaconda3\lib\site-packages (from pmdarima) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in c:\users\hp\anaconda3\lib\site-packages (from pmdarima) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\hp\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\hp\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hp\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
#check number of difference required for a stationary series

from pmdarima.arima.utils import ndiffs
y = data.Price
## Adf Test
print('ADF :', ndiffs(y, test='adf') )
# KPSS test
print('KPSS :' ,ndiffs(y, test='kpss'))
# PP test:
print('PP :' ,ndiffs(y, test='pp'))
# Out:
# ADF : 1
# KPSS : 1
# PP : 1

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(15,5), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2)
axes[0].plot(data.Price.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,5))
plot_pacf(data.Price.diff().dropna(), ax=axes[1])

plt.show()

# %%
fig, axes = plt.subplots(1, 2)
axes[0].plot(data.Price.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,1.2))
plot_acf(data.Price.diff().dropna(), ax=axes[1])

plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
# separate out a validation dataset
split_point = len(data)-152
dataset, validation = data[0:split_point], data[split_point:]
print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
dataset.to_csv('dataset.csv', header=False)
validation.to_csv('validation.csv', header=False)
# Out:
# Dataset 606, Validation 152

# %% [markdown]
# ### ARIMA

# %%
# load data
train = read_csv('dataset.csv', header=0, index_col=0, parse_dates=True)
# prepare data
X = train.values
X = X.astype('float32')

# %%
from statsmodels.tsa.arima.model import ARIMA

# Specify the order of the ARIMA model
order = (0, 1, 0)

# Create and fit the ARIMA model
model = ARIMA(X, order=order)
model_fit = model.fit()

# Forecast future values
forecast = model_fit.forecast(steps=152)[0]

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
from statsmodels.tsa.stattools import acf

# Create Training and Test
train = data.Price[:558].astype('float32')
test = data.Price[558:].astype('float32')

# %%
import pmdarima as pm

model = pm.auto_arima(data.Price, start_p=1, start_q=1,
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=1,           
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=11428.645, Time=0.29 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=11426.386, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=11427.401, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=11427.484, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=11425.922, Time=0.02 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.485 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  758
# Model:               SARIMAX(0, 1, 0)   Log Likelihood               -5711.961
# Date:                Thu, 18 May 2023   AIC                          11425.922
# Time:                        11:32:56   BIC                          11430.551
# Sample:                             0   HQIC                         11427.705
#                                 - 758
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      2.094e+05   2161.397     96.867      0.000    2.05e+05    2.14e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.54   Jarque-Bera (JB):             71419.80
# Prob(Q):                              0.46   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.27   Skew:                             3.91
# Prob(H) (two-sided):                  0.06   Kurtosis:                        49.94
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(7,5))
plt.show()

# %%
# Forecast
n_periods = 20
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = np.arange(len(data.Price), len(data.Price)+n_periods)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(data.Price,)
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("Final Forecast Usage")
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %% [markdown]
# ### SARIMA

# %%
# Plot
fig, axes = plt.subplots(2, 1, figsize=(17,7), dpi=100)

# Usual Differencing
axes[0].plot(data[:], label='Original Series')
axes[0].plot(data[:].diff(2), label='Usual Differencing')
axes[0].set_title('Usual Differencing')
axes[0].legend(loc='upper left', fontsize=10)


# Seasinal Dei
axes[1].plot(data[:], label='Original Series')
axes[1].plot(data[:].diff(12), label='Seasonal Differencing', color='green')
axes[1].set_title('Gols Price')
plt.legend(loc='upper left', fontsize=10)
plt.show()

# %%
# !pip3 install pyramid-arima
import pmdarima as pm

# Seasonal - fit stepwise auto-ARIMA
smodel = pm.auto_arima(data, start_p=1, start_q=1,
                         max_p=3, max_q=3, m=12,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

smodel.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=12071.411, Time=1.17 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=13135.622, Time=0.05 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=12099.122, Time=1.34 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=12534.239, Time=1.21 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=13152.612, Time=0.04 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=12240.975, Time=0.80 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=12068.104, Time=0.74 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=12080.408, Time=1.53 sec
#  ARIMA(1,0,1)(2,1,1)[12] intercept   : AIC=12069.976, Time=1.89 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=12062.266, Time=3.76 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=12060.281, Time=2.48 sec
#  ARIMA(0,0,1)(0,1,2)[12] intercept   : AIC=12534.450, Time=2.82 sec
#  ARIMA(1,0,0)(0,1,2)[12] intercept   : AIC=12073.703, Time=1.94 sec
#  ARIMA(2,0,1)(0,1,2)[12] intercept   : AIC=12062.282, Time=3.97 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=12062.158, Time=3.01 sec
#  ARIMA(0,0,0)(0,1,2)[12] intercept   : AIC=13130.983, Time=0.49 sec
#  ARIMA(0,0,2)(0,1,2)[12] intercept   : AIC=12306.286, Time=4.12 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=12060.905, Time=2.35 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=inf, Time=5.44 sec
#  ARIMA(1,0,1)(0,1,2)[12]             : AIC=12066.835, Time=1.34 sec
#
# Best model:  ARIMA(1,0,1)(0,1,2)[12] intercept
# Total fit time: 40.499 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                  758
# Model:             SARIMAX(1, 0, 1)x(0, 1, [1, 2], 12)   Log Likelihood               -6024.141
# Date:                                 Thu, 18 May 2023   AIC                          12060.281
# Time:                                         11:33:39   BIC                          12087.970
# Sample:                                              0   HQIC                         12070.953
#                                                  - 758
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     55.6728     24.338      2.288      0.022       7.972     103.374
# ar.L1          0.8141      0.005    152.702      0.000       0.804       0.825
# ma.L1          0.1699      0.012     14.543      0.000       0.147       0.193
# ma.S.L12      -0.4932      0.017    -29.532      0.000      -0.526      -0.461
# ma.S.L24       0.1033      0.010     10.550      0.000       0.084       0.122
# sigma2      4.379e+05      1e+04     43.595      0.000    4.18e+05    4.58e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.61   Jarque-Bera (JB):             95681.81
# Prob(Q):                              0.06   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.23   Skew:                            -2.46
# Prob(H) (two-sided):                  0.00   Kurtosis:                        58.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# Forecast
n_periods = 24
fitted, confint = smodel.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = pd.date_range(data.index[-1], periods = n_periods, freq='MS')

# make series for plotting purpose
fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.plot(data)
plt.plot(fitted_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("SARIMA - Final Forecast")
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
